# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Task 1

# %%
dark=cv2.imread(r"D:\Photos\pcd31.jpeg") 
showd=cv2.cvtColor(dark,cv2.COLOR_BGR2RGB)

# %%
rainbow=cv2.imread(r"D:\Photos\pcd32.jpeg") 
showr=cv2.cvtColor(rainbow,cv2.COLOR_BGR2RGB)

# %%
blue=cv2.imread(r"D:\Photos\pcd391.jpg") 
showb=cv2.cvtColor(blue,cv2.COLOR_BGR2RGB)

# %%
hist_values=cv2.calcHist([blue],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
hist_values.shape 
plt.plot(hist_values)

# %%
hist_values=cv2.calcHist([rainbow],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
hist_values.shape 
plt.plot(hist_values)

# %%
hist_values=cv2.calcHist([dark],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
hist_values.shape 
plt.plot(hist_values)

# %% [markdown]
# Task 2

# %%
img = blue 
color=('b','g','r')

# %%
for i, col in enumerate(color): 
    histr=cv2.calcHist([img],[i],None,[256],[0,256]) 
    plt.plot(histr,color=col) 
    plt.xlim([0,256])
    plt.ylim([0,5000]) 
plt.title('HISTOGRAM BLUE')
# Out:
# Text(0.5, 1.0, 'HISTOGRAM BLUE')

# %%
img = rainbow 
color=('b','g','r')

# %%
for i, col in enumerate(color): 
    histr=cv2.calcHist([img],[i],None,[256],[0,256]) 
    plt.plot(histr,color=col) 
    plt.xlim([0,256])
    plt.ylim([0,6000]) 
plt.title('HISTOGRAM RAINBOW')
# Out:
# Text(0.5, 1.0, 'HISTOGRAM RAINBOW')

# %%
img = dark 
color=('b','g','r')

# %%
for i, col in enumerate(color): 
    histr=cv2.calcHist([img],[i],None,[256],[0,256]) 
    plt.plot(histr,color=col) 
    plt.xlim([0,256])
    plt.ylim([0,5000]) 
plt.title('HISTOGRAM DARK')
# Out:
# Text(0.5, 1.0, 'HISTOGRAM DARK')
