# %%
import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# Task 1

# %%
img=cv2.imread(r"D:\Photos\pcd31.jpeg") 
plt.imshow(img)

# %% [markdown]
# Task 2

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB) 
plt.imshow(img)

# %% [markdown]
# Task 3

# %%
img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV) 
plt.imshow(img)

# %% [markdown]
# Task 4

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2HSV) 
plt.imshow(img)

# %% [markdown]
# Task 5

# %%
img=cv2.cvtColor(img,cv2.COLOR_RGB2HLS) 
plt.imshow(img)

# %% [markdown]
# Task 6

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB) 
plt.imshow(img)
